# %%
import pandas as pd
import numpy as np
import pickle

# %%
user = pd.read_pickle('users_final.pkl')

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47492 entries, 0 to 51383
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   isbn             47492 non-null  object
#  1   rank_mean        47492 non-null  object
#  2   rank_percentage  47492 non-null  object
#  3   review_title     47492 non-null  object
#  4   review_id        47492 non-null  object
#  5   review_rank      47492 non-null  object
#  6   review_text      47492 non-null  object
# dtypes: object(7)
# memory usage: 2.9+ MB

# %%
user.isbn.duplicated().sum()
# Out:
# 0

# %%
user.columns
# Out:
# Index(['isbn', 'rank_mean', 'rank_percentage', 'review_title', 'review_id',
#        'review_rank', 'review_text'],
#       dtype='object')

# %%
re = pd.read_pickle('recommend_cat_new.pkl')
re.head(2)
# Out:
#               isbn                                         title categoryName  \
# 198  9791165341909  달러구트 꿈 백화점 (50만 부 기념 드림 에디션) - 주문하신 꿈은 매진입니다           소설
# 559  9791161571188                      불편한 편의점 (40만부 기념 벚꽃 에디션)           소설
#
#      salesPoint  adult  rank                        genres          mood  \
# 198      379054  False     8  [역사, 동화, 로맨스, 미스터리, 판타지, 무협]      [행복, 위로]
# 559      330837  False    10                      [시대, 동화]  [위로, 힐링, 행복]
#
#                      interest
# 198  [일기, 동물, 사랑, 생각, 진로, 설득]
# 559      [시간, 심리, 관계, 사랑, 생각]

# %%
re = pd.merge(re, user,how = 'left', on = 'isbn')
re.head(2)
# Out:
#             isbn                                         title categoryName  \
# 0  9791165341909  달러구트 꿈 백화점 (50만 부 기념 드림 에디션) - 주문하신 꿈은 매진입니다           소설
# 1  9791161571188                      불편한 편의점 (40만부 기념 벚꽃 에디션)           소설
#
#    salesPoint  adult  rank                        genres          mood  \
# 0      379054  False     8  [역사, 동화, 로맨스, 미스터리, 판타지, 무협]      [행복, 위로]
# 1      330837  False    10                      [시대, 동화]  [위로, 힐링, 행복]
#
#                    interest rank_mean         rank_percentage  \
# 0  [일기, 동물, 사랑, 생각, 진로, 설득]     [9.2]  [78%, 17%, 3%, 1%, 1%]
# 1      [시간, 심리, 관계, 사랑, 생각]     [9.2]  [74%, 20%, 5%, 1%, 1%]
#
#                                         review_title  \
# 0  [달러구트 꿈 백화점_ 당신은 오늘 어떤 꿈을 꾸고 싶나요?, 마케팅의 승리책., ...
# 1  [불편한 편의점, 불편하지만 자꾸 가고 싶은 편의점, 따듯한 편의점, 우리의 또다른...
#
#                                            review_id  \
# 0  [2****a, s*****y, g*******7, g*******g, 이****이...
# 1  [부***주, g*******g, n***8, J*y, 꿈*******자, 해**이...
#
# ...

# %%
re['review_text'][0]
# Out:
# ['\n\n\xa0\n\xa0\n\xa0\n\xa0\n꿈을 꿀 수 있다는 건 행복한 거야!\n따뜻하고 감동적이고 신비한 마법의 묘약을 삼킨 것 같은 아름다운 동화!\xa0 \n\xa0\n\xa0\n\xa0\n“손님, ‘옛 친구를 만나는 꿈’은 어떠세요? 2층 추억코너에 딱 하나 남았어요! 네? 어떤 친구가 나오냐고요? 그건 저도 모른답니다. 아마도 손님 기억 속에 있는 어릴 적 친구 중 1명이 나올 거예요.”\n“몰디브에서 3박 4일 휴가 보내는 꿈‘은 들어오자마자 다 팔렸어요.”\n(…) “전 층 전량 매진 임박. 매진 임박입니다!” / 41p \n\xa0\n\xa0\n\xa0\n\xa0\xa0 이곳은 먼 옛날부터 사람들에게 수면에 관련된 상품을 판매하면서 발달해온 도시다. 잠옷 차림으로 돌아다니는 사람들, 숙면을 취하는 데 도움을 주는 요리를 판매하고 있는 뒷골목의 푸드트럭, 잠든 손님들이 옷을 훌렁훌렁 벗고 다니지 않도록 100벌이 넘는 수면용 가운을 짊어지고 손님들을 쫓아다니며 옷을 입히는 녹틸루카들. 그 중에서도 화려하고 고풍스러운 건물로 사람들의 시선을 끄는 ‘달러구트의 꿈 백화점’은 이 도시의 랜드마크다. 이름에서 알 수 있듯 꿈 백화점은 손님들에게 꿈을 판매하는 곳이다. 자세히 들여다보자면 1층에서는 아주 고가의 인기상품, 한정판, 예약상품들만을 소량 취급하고, 2층에서는 소소한 여행이나 친구를 만나는 꿈 또는 맛있는 음식을 먹는 꿈 등 평범한 일상에 가까운 꿈들을 판매한다. 3층은 하늘을 나는 꿈과 같이 액티비티한 꿈을, 4층은 잠을 많이 자는 동물들과 온종일 잠만 자는 아기 손님들이 많기로 유명하다. 마지막 5층에서는 유효기간이 임박하거나 예약해놓고 가져가지 않은 꿈을 할인 판매하고 있는데, 여기저기 한꺼번에 쏟아놓은 꿈 박스 속에서 운이 좋으면 저렴한 가격에 상당히 좋은 꿈을 건질 수도 있다. \n\xa0\n\xa0\n\xa0\n\xa0\xa0 페니는 젊은이들에게 아주 인기가 좋은, 바로 이 달러구트 꿈 백화점에서 일을 할 수 있게 된 
# ...

# %%
re['review_text'][0][9]
# Out:
# '\n판매량이 엄청난 베스트셀러 소설을 산 건 오랜만인 것 같다.꿈을 파는 백화점이라...정말 참신했기 때문에..하지만...너무 유치해서..진심 중도하차 할 뻔했다. 특히 2, 3장은 많이... 별로였다..뭔가 옛날 드라마 인소 같은 감성?....그래도 꾹 참고 읽다보니 괜찮은 주제가 있긴 했다...노쇼 문제, 반려동물의 외로움, 결과만 동경하는 사람들, 떠난 이들의 남겨진 마음 등 현대 사회의 여러 문제점에 다시 한번 생각해보는 기회가 된 것 같다. 참고 읽으니 그럭저럭 읽을만 했는데 별로  추천은 안 하고 싶다...그냥 도서관 가서 읽는 정도로만 ..\n'

# %%
re.tail(2)
# Out:
#                 isbn       title categoryName  salesPoint  adult  rank  \
# 54372  9791188519354  서번트 리더의 품격         자기계발           0  False     0
# 54373  9791190710350      오만과 편견           소설           0  False     0
#
#          genres          mood                                interest  \
# 54372        []  [행복, 도전, 열망]                       [리더십, 생각, 성공, 인생]
# 54373  [시대, 동화]  [도전, 열정, 행복]  [사랑, 심리, 인간, 인생, 청춘, 관계, 페미니즘, 생각, 일상]
#
#       rank_mean         rank_percentage review_title review_id review_rank  \
# 54372        []                      []           []        []          []
# 54373    [10.0]  [100%, 0%, 0%, 0%, 0%]     [오만과 편견]    [할**장]        [5점]
#
#                                              review_text
# 54372                                                 []
# 54373  [\n\n \n오만과 편견은 1813년 출판된 이래 한국에도 여러 출판사를 통해 번...

# %%
re_user = re[['isbn','title','review_id', 'review_rank']]
re_user
# Out:
#                 isbn                                          title  \
# 0      9791165341909   달러구트 꿈 백화점 (50만 부 기념 드림 에디션) - 주문하신 꿈은 매진입니다
# 1      9791161571188                       불편한 편의점 (40만부 기념 벚꽃 에디션)
# 2      9791192186313                                   시맨틱 에러 포토에세이
# 3      9788954681179                                  밝은 밤 (별밤 에디션)
# 4      9791165343729                      달러구트 꿈 백화점 2 - 단골손님을 찾습니다
# ...              ...                                            ...
# 54369  9791192227726    [큰글씨책] 천직을 넘어 전설을 꿈꾸다 - 택시대학 정태성의 끝나지 않은 도전
# 54370  9791192227658  [큰글씨책] 완벽한 소통법 - 일, 관계, 갈등이 술술 풀리는 커뮤니케이션의 법칙
# 54371  9791164409464           희망을 모아 나누는 우리 - 농업 공동체 ‘해 뜨는 마을’ 이야기
# 54372  9791188519354                                     서번트 리더의 품격
# 54373  9791190710350                                         오만과 편견
#
#                                                review_id  \
# 0      [2****a, s*****y, g*******7, g*******g, 이****이...
# ...

# %%
re_user['review_id'][0]
# Out:
# ['2****a',
#  's*****y',
#  'g*******7',
#  'g*******g',
#  '이****이',
#  'k*******8',
#  'a******9',
#  'J*y',
#  '블*',
#  'y********7']

# %%
df = pd.DataFrame(columns = ['review_id','review_rank'])
for i in range(len(re)):
    df_out = pd.DataFrame([re_user['review_id'][i],re_user['review_rank'][i]], index = ['review_id','review_rank']).T
    df = pd.concat([df, df_out], ignore_index=True)

# %%
#df.to_pickle('review_id_rank', protocol=4)

# %%
df_id_rank = pd.read_pickle('review_id_rank')

# %%
df_id_rank1 = df_id_rank.groupby('review_id').count().reset_index().sort_values('review_rank', ascending = False)
df_id_rank1
# Out:
#        review_id  review_rank
# 7467          나*         1311
# 3492   k*******2         1139
# 10138         블*          970
# 7387   꿈*******자          956
# 13353         지*          903
# ...          ...          ...
# 8673       런***미            1
# 8672       런***니            1
# 8671         럭*퍼            1
# 8670         럭*리            1
# 15647      Ｋ***Ｏ            1
#
# [15648 rows x 2 columns]

# %%
df_id_rank1[df_id_rank1['review_rank'] >= 10]
# Out:
#         review_id  review_rank
# 7467           나*         1311
# 3492    k*******2         1139
# 10138          블*          970
# 7387    꿈*******자          956
# 13353          지*          903
# ...           ...          ...
# 15639         힘*내           10
# 15465         화*이           10
# 15578        흥**들           10
# 1548   b********2           10
# 2524     f******w           10
#
# [3220 rows x 2 columns]

# %%
d1 = pd.DataFrame([ re_user['review_id'][0],re_user['review_rank'][0]],index = ['review_id','review_rank']).T
d1
# Out:
#     review_id review_rank
# 0      2****a          5점
# 1     s*****y          1점
# 2   g*******7          1점
# 3   g*******g          4점
# 4      이****이          1점
# 5   k*******8          1점
# 6    a******9          2점
# 7         J*y          4점
# 8          블*          4점
# 9  y********7          2점

# %%
pd.merge(re[['isbn']].loc[0], d1, how='cross')
# Out:
#                0   review_id review_rank
# 0  9791165341909      2****a          5점
# 1  9791165341909     s*****y          1점
# 2  9791165341909   g*******7          1점
# 3  9791165341909   g*******g          4점
# 4  9791165341909      이****이          1점
# 5  9791165341909   k*******8          1점
# 6  9791165341909    a******9          2점
# 7  9791165341909         J*y          4점
# 8  9791165341909          블*          4점
# 9  9791165341909  y********7          2점

# %%
d3 = pd.DataFrame(columns = ['0', 'review_id','review_rank'])
for i in range(len(re)):
    d1 = pd.DataFrame([re_user['review_id'][i],re_user['review_rank'][i]],index = ['review_id','review_rank']).T
    d2 = pd.merge(left = re[['isbn']].loc[i], right = d1, how='cross')
    d3 = pd.concat([d3,d2],ignore_index=True)

# %%
re[['isbn','title']].loc[0]
# Out:
# isbn                                    9791165341909
# title    달러구트 꿈 백화점 (50만 부 기념 드림 에디션) - 주문하신 꿈은 매진입니다
# Name: 0, dtype: object

# %%
df
# Out:
# Empty DataFrame
# Columns: [isbn, review_id, review_rank]
# Index: []

# %%
re_user[['isbn','title']]
# Out:
#                 isbn                                          title
# 0      9791165341909   달러구트 꿈 백화점 (50만 부 기념 드림 에디션) - 주문하신 꿈은 매진입니다
# 1      9791161571188                       불편한 편의점 (40만부 기념 벚꽃 에디션)
# 2      9791192186313                                   시맨틱 에러 포토에세이
# 3      9788954681179                                  밝은 밤 (별밤 에디션)
# 4      9791165343729                      달러구트 꿈 백화점 2 - 단골손님을 찾습니다
# ...              ...                                            ...
# 54369  9791192227726    [큰글씨책] 천직을 넘어 전설을 꿈꾸다 - 택시대학 정태성의 끝나지 않은 도전
# 54370  9791192227658  [큰글씨책] 완벽한 소통법 - 일, 관계, 갈등이 술술 풀리는 커뮤니케이션의 법칙
# 54371  9791164409464           희망을 모아 나누는 우리 - 농업 공동체 ‘해 뜨는 마을’ 이야기
# 54372  9791188519354                                     서번트 리더의 품격
# 54373  9791190710350                                         오만과 편견
#
# [54374 rows x 2 columns]

# %%
dff = pd.DataFrame([re_user['isbn'][0], re_user['review_id'][0],re_user['review_rank'][0]], index = ['isbn','review_id','review_rank']).T
dff
# Out:
#             isbn                                          review_id  \
# 0  9791165341909  [2****a, s*****y, g*******7, g*******g, 이****이...
#
#                                 review_rank
# 0  [5점, 1점, 1점, 4점, 1점, 1점, 2점, 4점, 4점, 2점]

# %%
re_user['isbn'][0]
# Out:
# '9791165341909'
